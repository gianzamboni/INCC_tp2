# %%
import gensim, os
import codecs
import re
from ipywidgets import IntProgress, HTML, VBox
from IPython.display import display
import nltk

# %%
#Esto es para mostrar barras de progreso en los codigos, no hagan caso
def log_progress(sequence, every=None, size=None):

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{index} / ?'.format(index=index)
                else:
                    progress.value = index
                    label.value = u'{index} / {size}'.format(
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = str(index or '?')

# %%
#Cargo todas las noticias de clarin
noticiasClarin = []
for filename in log_progress(os.listdir("NoticiasClarin")):  #Por cada archivo en NoticiasClarin
    f = codecs.open(os.path.join("NoticiasClarin", filename), "r", "utf-8") #Abrir el archivo con codificacion "utf-8"
    content = f.read().replace("\xa0", " ").replace("\u200b", "") #Leer el archivo (Leer noticia)
    noticiasClarin.append(content) #Agregar noticia a la lista de noticias de clarin
    f.close() #Cerrar el archivo

# %%
#Cargo todas las noticias de pagina 12
noticiasPagina12 = []
for filename in log_progress(os.listdir("NoticiasPagina12")):
    content = ""
    try:
        f = codecs.open(os.path.join("NoticiasPagina12", filename), "r", "cp1252")
        content = f.read()
        f.close()
    except:
        f.close()
        f = codecs.open(os.path.join("NoticiasPagina12", filename), "r", "utf-8")
        content = f.read()
        f.close()
    noticiasPagina12.append(content)

# %%
todasLasNoticias = []
todasLasNoticias.extend(noticiasClarin)
todasLasNoticias.extend(noticiasPagina12)

# %%
clean_noticias = [reg_num.sub(" num ",noticia).replace("\n", " ") for noticia in log_progress(todasLasNoticias)]

# %%
stopwords = nltk.corpus.stopwords.words("spanish")
[palabra for palabra in re.split(r'\W+', clean_noticias[2365].lower()) if palabra not in stopwords and palabra.isalpha()]
# Out:
# ['estudiosos',
#  'del',
#  'deporte',
#  'consideran',
#  'que',
#  'el',
#  'primer',
#  'partido',
#  'internacional',
#  'del',
#  'fútbol',
#  'moderno',
#  'fue',
#  'el',
#  'que',
#  'jugaron',
#  'inglaterrra',
#  'y',
#  'escocia',
#  'el',
#  'num',
#  'de',
#  'marzo',
#  'de',
#  'num',
#  'pero',
#  'que',
#  'además',
#  'este',
#  'dio',
#  'inicio',
#  'a',
#  'la',
#  'llamada',
#  'diplomacia',
#  'del',
#  'fútbol',
#  'al',
#  'permitir',
#  'que',
#  'se',
#  'expresaron',
#  'intereses',
#  'y',
#  'relaciones',
#  'de',
#  'dos',
#  'naciones',
#  'a',
#  'través',
#  'de',
#  'esa',
#  'práctica',
#  'entonces',
#  'se',
#  'jugaba',
#  'la',
#  'fuerte',
#  'identidad',
#  'de',
#  'los',
#  'escoceses',
#  'ganadores',
#  'del',
#  'encuentro',
#  'decenas',
#  'de',
#  'naciones',
#  'utilizaron',
#  'este',
#  'recurso',
#  'años',
#  'después',
#  'con',
#  'distintos',
#  'grados',
#  'de',
#  'éxito',
#  'y',
#  'emoción',
#  'porque',
#  'además',
#  'en',
#  'la',
#  'mayoría',
#  'de',
#  'los',
#  'casos',
#  'se',
#  'utilizó',
#  'para',
#  'descompromir',
#  'conflictos',
#  'mauricio',
#  'macri',
#  'comenzó',
#  'apelando',
#  'a',
#  'este',
#  'tipo',
#  'de',
#  'diplomacia',
#  'el',
#  'num',
#  'de',
#  'diciembre',
#  'pasado',
#  'un',
#  'día',
#  'antes',
#  'de',
#  'asumir',
#  'como',
#  'presidente',
#  'cuando',
#  'limó',
#  'asperezas',
#  'con',
#  'evo',
#  'morales',
#  'en',
#  'un',
#  'partido',
#  'de',
#  'fútbol',
#  'parece',
#  'haberlo',
#  'incorporado',
#  'también',
#  'a',
#  'su',
#  'gestión',
#  'ya',
#  'que',
#  'ahora',
#  'volverá',
#  'a',
#  'usarla',
#  'con',
#  'dos',
#  'líderes',
#  'europeos',
#  'el',
#  'premier',
#  'italiano',
#  'y',
#  'el',
#  'presidente',
#  'francés',
#  'yendo',
#  'a',
#  'visitar',
#  'la',
#  'cancha',
#  'de',
#  'boca',
#  'junior',
#  'donde',
#  'el',
#  'mandatario',
#  'argentino',
#  'le',
#  'cedió',
#  'protagonismo',
#  'al',
#  'aliado',
#  'y',
#  'anfitrión',
#  'el',
#  'presidente',
#  'del',
#  'club',
#  'daniel',
#  'angelici',
#  'el',
#  'martes',
#  'pasado',
#  'fue',
#  'renzi',
#  'un',
#  'fanántico',
#  'declarado',
#  'de',
#  'la',
#  'fiorentina',
#  'el',
#  'equipo',
#  'de',
#  'florencia',
#  'de',
#  'donde',
#  'siendo',
#  'alcalde',
#  'saltó',
#  'a',
#  'la',
#  'palestra',
#  'nacional',
#  'pues',
#  'renzi',
#  'se',
#  'dio',
#  'el',
#  'gusto',
#  'y',
#  'ese',
#  'martes',
#  'num',
#  'después',
#  'de',
#  'visitar',
#  'con',
#  'macri',
#  'las',
#  'obras',
#  'de',
#  'soterramiento',
#  'del',
#  'ferrocarril',
#  'sarmiento',
#  'recorrió',
#  'la',
#  'bombonera',
#  'con',
#  'angelici',
#  'renzi',
#  'en',
#  'todo',
#  'momento',
#  'bromeó',
#  'con',
#  'que',
#  'hasta',
#  'en',
#  'el',
#  'encuentro',
#  'que',
#  'mantuvieron',
#  'compenhague',
#  'hace',
#  'unos',
#  'años',
#  'siendo',
#  'ambos',
#  'jefes',
#  'de',
#  'gobierno',
#  'de',
#  'sus',
#  'resepctivas',
#  'ciudades',
#  'la',
#  'fiorentina',
#  'y',
#  'boca',
#  'estuvieron',
#  'en',
#  'el',
#  'primer',
#  'lugar',
#  'de',
#  'sus',
#  'conversaciones',
#  'antes',
#  'había',
#  'pasado',
#  'por',
#  'la',
#  'cancha',
#  'el',
#  'presidente',
#  'de',
#  'bulgaria',
#  'rosen',
#  'plevneliev',
#  'un',
#  'apasionado',
#  'hincha',
#  'de',
#  'fútbol',
#  'amigo',
#  'personal',
#  'de',
#  'hristo',
#  'stoichkov',
#  'astro',
#  'de',
#  'fútbol',
#  'de',
#  'su',
#  'país',
#  'que',
#  'brilló',
#  'en',
#  'el',
#  'barcelona',
#  'plevneliev',
#  'vivió',
#  'con',
#  'emoción',
#  'cada',
#  'minuto',
#  'de',
#  'su',
#  'visita',
#  'a',
#  'las',
#  'instalaciones',
#  'xeneizes',
#  'y',
#  'no',
#  'pudo',
#  'resistirse',
#  'a',
#  'hacer',
#  'jueguitos',
#  'en',
#  'el',
#  'césped',
#  'de',
#  'la',
#  'bombonera',
#  'es',
#  'más',
#  'su',
#  'paso',
#  'por',
#  'el',
#  'estadio',
#  'de',
#  'boca',
#  'donde',
#  'jugó',
#  'maradona',
#  'uno',
#  'de',
#  'sus',
#  'ídolos',
#  'fue',
#  'tópico',
#  'obligado',
#  'en',
#  'cada',
#  'reunión',
#  'su',
#  'tuvo',
#  'con',
#  'funcionarios',
#  'argentinos',
#  'mañana',
#  'le',
#  'toca',
#  'el',
#  'turno',
#  'al',
#  'presidente',
#  'de',
#  'francia',
#  'quien',
#  'por',
#  'cierto',
#  'llegó',
#  'hoy',
#  'al',
#  'país',
#  'con',
#  'un',
#  'grupo',
#  'de',
#  'personalidades',
#  'de',
#  'la',
#  'cultura',
#  'y',
#  'el',
#  'deporte',
#  'franco',
#  'argentinos',
#  'entre',
#  'ellos',
#  'el',
#  'futbolista',
#  'david',
#  'trezeguet',
#  'que',
#  'irá',
#  'con',
#  'hollande',
#  'a',
#  'visitar',
#  'el',
#  'plantel',
#  'de',
#  'boca',
#  'para',
#  'hollande',
#  'como',
#  'para',
#  'los',
#  'franceses',
#  'el',
#  'fútbol',
#  'también',
#  'está',
#  'en',
#  'primera',
#  'línea',
#  'de',
#  'su',
#  'agenda',
#  'popular',
#  'y',
#  'basta',
#  'recordar',
#  'que',
#  'él',
#  'mismo',
#  'estaba',
#  'en',
#  'el',
#  'estadio',
#  'de',
#  'francia',
#  'mirando',
#  'un',
#  'partido',
#  'entre',
#  'la',
#  'selección',
#  'de',
#  'su',
#  'país',
#  'y',
#  'la',
#  'de',
#  'alemania',
#  'aquel',
#  'trágico',
#  'num',
#  'de',
#  'noviembre',
#  'de',
#  'num',
#  'cuando',
#  'se',
#  'produjeron',
#  'los',
#  'múltiples',
#  'atentados',
#  'en',
#  'parís',
#  'incluyendo',
#  'uno',
#  'en',
#  'las',
#  'inmediaciones',
#  'de',
#  'la',
#  'cancha',
#  'de',
#  'donde',
#  'debió',
#  'ser',
#  'evacuado',
#  'de',
#  'emergencia',
#  'el',
#  'mandatario',
#  'son',
#  'pedidos',
#  'que',
#  'hacen',
#  'los',
#  'líderes',
#  'que',
#  'nos',
#  'visitan',
#  'no',
#  'hay',
#  'dudas',
#  'de',
#  'que',
#  'boca',
#  'es',
#  'un',
#  'emblema',
#  'argentino',
#  'dijo',
#  'al',
#  'ser',
#  'consultado',
#  'por',
#  'clarín',
#  'fulvio',
#  'pompeo',
#  'secretario',
#  'de',
#  'asuntos',
#  'estratégicos',
#  'de',
#  'la',
#  'casa',
#  'rosada',
#  'pedirá',
#  'también',
#  'barack',
#  'obama',
#  'visitar',
#  'la',
#  'bombonera',
#  'el',
#  'presidente',
#  'de',
#  'los',
#  'estados',
#  'unidos',
#  'estará',
#  'en',
#  'la',
#  'argentina',
#  'el',
#  'num',
#  'y',
#  'num',
#  'de',
#  'marzo',
#  'pero',
#  'por',
#  'ahora',
#  'todos',
#  'responden',
#  'que',
#  'la',
#  'agenda',
#  'es',
#  'secreta',
#  'porque',
#  'todavía',
#  'la',
#  'están',
#  'armando',
#  '']
